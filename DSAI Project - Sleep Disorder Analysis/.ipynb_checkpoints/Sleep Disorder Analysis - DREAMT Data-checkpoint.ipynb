# %% [markdown]
# # Sleep Disorder Analysis

# %% [markdown]
# ## Downloading Dataset

# %%
import opendatasets as od
 
od.download(
    "https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: mindhawk
# Your Kaggle Key: ········
# Dataset URL: https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# Downloading sleep-health-and-lifestyle-dataset.zip to .\sleep-health-and-lifestyle-dataset
# 100%|█████████████████████████████████████████████████████████████████████████████| 2.54k/2.54k [00:00<00:00, 1.30MB/s]

# %% [markdown]
# ## Importing all the required Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn import ensemble
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import Concatenate, Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam,SGD,RMSprop,Adagrad,Adadelta,Nadam,Adamax
from tensorflow.keras import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from IPython.display import clear_output
import os

# %% [markdown]
# ## The Data

# %%
file =('sleep-health-and-lifestyle-dataset\\Sleep_health_and_lifestyle_dataset.csv')
data = pd.read_csv(file)
 
# displaying the contents of the CSV file
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# 1         125/80          75        10000           None
# 2         125/80          75        10000           None
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
# Splitting Blood Pressure into two column values, Systolic and Diastolic respectively
data[['Systolic', 'Diastolic']] = data['Blood Pressure'].str.split('/', expand=True)
data['Systolic'] = data['Systolic'].astype(int)
data['Diastolic'] = data['Diastolic'].astype(int)

# Mapping 0 for Male and 1 for Female to convert to numerical data
genMap = {'Male': 0, 'Female': 1}
data.Gender = data.Gender.map(genMap)

# Mapping 0 for Normal, 1 for Normal Weight, 2 for Overweight and 3 for Obese to convert to numerical data
bmiMap = {'Normal': 0, 'Normal Weight': 1, 'Overweight':2, 'Obese': 3}
data['BMI Category'] = data['BMI Category'].map(bmiMap)

# Mapping 0 for Apnea, 1 for None and 2 for Insomnia to convert to numerical data
diseaseMap = {'Sleep Apnea': 0, 'None':1, 'Insomnia': 2}
data['Sleep_Disorder_Target'] = data['Sleep Disorder'].map(diseaseMap)

# Dropping irrelevant columns  / split columns
data = data.drop(['Sleep Disorder', 'Person ID', 'Occupation', 'Blood Pressure'], axis = 1)

data.head()
# Out:
#    Gender  Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0       0   27             6.1                 6                       42
# 1       0   28             6.2                 6                       60
# 2       0   28             6.2                 6                       60
# 3       0   28             5.9                 4                       30
# 4       0   28             5.9                 4                       30
#
#    Stress Level  BMI Category  Heart Rate  Daily Steps  Systolic  Diastolic  \
# 0             6             2          77         4200       126         83
# 1             8             0          75        10000       125         80
# 2             8             0          75        10000       125         80
# 3             8             3          85         3000       140         90
# 4             8             3          85         3000       140         90
#
#    Sleep_Disorder_Target
# 0                      1
# 1                      1
# 2                      1
# 3                      0
# 4                      0

# %%
# Displaying Correlation of Target with each feature
data.corr()['Sleep_Disorder_Target']
# Out:
# Gender                    -0.253415
# Age                       -0.232000
# Sleep Duration            -0.177552
# Quality of Sleep          -0.179592
# Physical Activity Level   -0.433214
# Stress Level               0.036058
# BMI Category              -0.029101
# Heart Rate                -0.205987
# Daily Steps               -0.342098
# Systolic                  -0.241786
# Diastolic                 -0.310051
# Sleep_Disorder_Target      1.000000
# Name: Sleep_Disorder_Target, dtype: float64

# %% [markdown]
# ### Describing the data

# %%
data.describe()
# Out:
#            Gender         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean     0.494652   42.184492        7.132086          7.312834
# std      0.500641    8.673133        0.795657          1.196956
# min      0.000000   27.000000        5.800000          4.000000
# 25%      0.000000   35.250000        6.400000          6.000000
# 50%      0.000000   43.000000        7.200000          7.000000
# 75%      1.000000   50.000000        7.800000          8.000000
# max      1.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# count               374.000000    374.000000    374.000000  374.000000
# mean                 59.171123      5.385027      0.927807   70.165775
# std                  20.830804      1.774526      1.010734    4.135676
# min                  30.000000      3.000000      0.000000   65.000000
# 25%                  45.000000      4.000000      0.000000   68.000000
# 50%                  60.000000      5.000000      0.000000   70.000000
# 75%                  75.000000      7.000000      2.000000   72.000000
# max                  90.000000      8.000000      3.000000   86.000000
#
#         Daily Steps    Systolic   Diastolic  Sleep_Disorder_Target
# count    374.000000  374.000000  374.000000             374.000000
# mean    6816.844920  128.553476   84.649733               0.997326
# std     1617.915679    7.748118    6.161611               0.644626
# min     3000.000000  115.000000   75.000000               0.000000
# 25%     5600.000000  125.000000   80.000000               1.000000
# 50%     7000.000000  130.000000   85.000000               1.000000
# 75%     8000.000000  135.000000   90.000000               1.000000
# max    10000.000000  142.000000   95.000000               2.000000

# %% [markdown]
# ## Scaling the Dataset

# %%
# Initialize the scaler
scaler = MinMaxScaler()

# Exclude 'Person ID' and non-numeric columns
columns_to_normalize = ['Gender', 'Age', 'Sleep Duration', 'Quality of Sleep', 'Physical Activity Level',
                         'Stress Level', 'BMI Category', 'Heart Rate', 'Daily Steps', 'Systolic', 'Diastolic']

# Apply Min-Max Scaling only to the selected numeric columns
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# %%
y_data = data['Sleep_Disorder_Target']
data = data.drop(['Sleep_Disorder_Target'], axis = 1)

# %%
data.head()
# Out:
#    Gender      Age  Sleep Duration  Quality of Sleep  Physical Activity Level  \
# 0     0.0  0.00000        0.111111               0.4                      0.2
# 1     0.0  0.03125        0.148148               0.4                      0.5
# 2     0.0  0.03125        0.148148               0.4                      0.5
# 3     0.0  0.03125        0.037037               0.0                      0.0
# 4     0.0  0.03125        0.037037               0.0                      0.0
#
#    Stress Level  BMI Category  Heart Rate  Daily Steps  Systolic  Diastolic
# 0           0.6      0.666667    0.571429     0.171429  0.407407       0.40
# 1           1.0      0.000000    0.476190     1.000000  0.370370       0.25
# 2           1.0      0.000000    0.476190     1.000000  0.370370       0.25
# 3           1.0      1.000000    0.952381     0.000000  0.925926       0.75
# 4           1.0      1.000000    0.952381     0.000000  0.925926       0.75

# %% [markdown]
# ## HeatMap to represent co-relation

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Applying PCA for dimensionality reduction

# %%
pca_data = PCA(n_components = 0.95) #Keeping 95% variance in the data.
X_data = pca_data.fit_transform(data)
pca_df = pd.DataFrame(X_data, columns = [f'PC{i+1}' for i in range(X_data.shape[1])])

# %%
explained_variance = pca_data.explained_variance_ratio_
explained_variance
# Out:
# array([0.35631629, 0.29125299, 0.16613399, 0.10033979, 0.03390281,
#        0.02078562])

# %%
pca_df['Sleep_Disorder_Target'] = y_data
pca_df.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -0.695531  0.420083  0.385407  0.320670  0.445274  0.159853
# 1 -0.956148  0.295033 -0.144652 -0.458087 -0.131212  0.017546
# 2 -0.956148  0.295033 -0.144652 -0.458087 -0.131212  0.017546
# 3 -0.650163  1.281758  0.607187  0.590807  0.432989 -0.143782
# 4 -0.650163  1.281758  0.607187  0.590807  0.432989 -0.143782
#
#    Sleep_Disorder_Target
# 0                      1
# 1                      1
# 2                      1
# 3                      0
# 4                      0

# %%
# Creating backup datasets
ml_data = dl_data = pca_df

# %%
# One-hot encode the 'Sleep_Disorder_Target' column for use in Neural Networks
dl_data = pd.get_dummies(dl_data, columns=['Sleep_Disorder_Target'], dtype=int)
# Rename the new columns
dl_data = dl_data.rename(columns={
    'Sleep_Disorder_Target_0': 'Apnea',
    'Sleep_Disorder_Target_1': 'Normal',
    'Sleep_Disorder_Target_2': 'Insomnia'
})

dl_data.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6  Apnea  Normal  \
# 0 -0.695531  0.420083  0.385407  0.320670  0.445274  0.159853      0       1
# 1 -0.956148  0.295033 -0.144652 -0.458087 -0.131212  0.017546      0       1
# 2 -0.956148  0.295033 -0.144652 -0.458087 -0.131212  0.017546      0       1
# 3 -0.650163  1.281758  0.607187  0.590807  0.432989 -0.143782      1       0
# 4 -0.650163  1.281758  0.607187  0.590807  0.432989 -0.143782      1       0
#
#    Insomnia
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# ## Randomly splitting data into training and testing set

# %%
X = dl_data.drop(columns=['Apnea', 'Normal', 'Insomnia'])  # All features (excluding the target columns)
y = dl_data[['Apnea', 'Normal', 'Insomnia']]  # One-hot encoded target

# Stratified split to keep the same distribution of classes in both train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,   # 80-20 train-test split (can adjust as per your needs)
    random_state=42, # For reproducibility
    stratify=y       # Ensures same distribution of classes in both train and test
)

print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Training set size: 299
# Test set size: 75

# %% [markdown]
# ## Model Design

# %%
model=Sequential()
# Input layer
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())  # Batch Normalization for better training stability
model.add(Dropout(0.3))  # Dropout to prevent overfitting
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization for better training stability
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())  # Batch Normalization for better training stability
model.add(Dropout(0.3))
# Output layer with softmax for multi-class classification (3 classes)
model.add(Dense(3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16)                64
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 3,555
# Trainable params: 3,331
# Non-trainable params: 224
# _________________________________________________________________

# %% [markdown]
# ## ####

# %%
input = Input(shape = X_train.shape[1])
hidden_1 = Dense(1024, activation = 'relu')(input)
hidden_2 = Dense(512, activation = 'sigmoid')(hidden_1)
hidden_3 = Dense(256, activation = 'tanh')(hidden_2)
hidden_11 = Dense(128, activation = 'sigmoid')(hidden_3)
hidden_12 = Dense(64, activation = 'relu')(hidden_11)
hidden_21 = Dense(128, activation = 'sigmoid')(hidden_3)
hidden_22 = Dense(64, activation = 'relu')(hidden_21)
hidden_31 = Dense(128, activation = 'sigmoid')(hidden_3)
hidden_32 = Dense(64, activation = 'relu')(hidden_31)
concat = Concatenate()([hidden_12, hidden_22, hidden_32])
hidden_4 = Dense(32, activation = 'sigmoid')(concat)
hidden_511 = Dense(128, activation = 'sigmoid')(hidden_4)
hidden_512 = Dense(64, activation = 'relu')(hidden_511)
hidden_521 = Dense(128, activation = 'sigmoid')(hidden_4)
hidden_522 = Dense(64, activation = 'relu')(hidden_521)
hidden_531 = Dense(128, activation = 'sigmoid')(hidden_4)
hidden_532 = Dense(64, activation = 'relu')(hidden_531)
concat2 = Concatenate()([hidden_512, hidden_522, hidden_532])
hidden_5 = Dense(32, activation = 'tanh')(concat2)
output = Dense(3, activation = 'softmax')(hidden_5)

model = Model(inputs = [input], outputs = [output])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024)         7168        input_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          524800      dense_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131328      dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          32896       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          32896       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          32896       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           8256        dense_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           8256        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           8256        dense_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 192)          0           dense_8[0][0]
#                                                                  dense_10[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 32)           6176        concatenate[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          4224        dense_13[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          4224        dense_13[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 128)          4224        dense_13[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 64)           8256        dense_14[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 64)           8256        dense_16[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 64)           8256        dense_18[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 192)          0           dense_15[0][0]
#                                                                  dense_17[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 32)           6176        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 3)            99          dense_20[0][0]
# ==================================================================================================
# Total params: 836,643
# Trainable params: 836,643
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compiling and Fitting the model

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['AUC', 'accuracy', 'Precision', 'Recall'])

early_stopping = EarlyStopping(monitor='val_loss',  # or 'val_accuracy'
                               patience=3,  # Number of epochs with no improvement after which training will be stopped
                               restore_best_weights=True)  # Restore the best model weights

# Train the model
checkpoint = ModelCheckpoint('best_model.h5', monitor='val_accuracy', save_best_only=True,verbose=1, mode='max')
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_test, y_test),callbacks=[checkpoint])
# Out:
# Epoch 1/150
# 10/10 [==============================] - 1s 44ms/step - loss: 0.9702 - auc: 0.6673 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00001: val_accuracy improved from -inf to 0.58667, saving model to best_model.h5
# Epoch 2/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9672 - auc: 0.6815 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00002: val_accuracy did not improve from 0.58667
# Epoch 3/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9659 - auc: 0.6954 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9654 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00003: val_accuracy did not improve from 0.58667
# Epoch 4/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9682 - auc: 0.6804 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9671 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00004: val_accuracy did not improve from 0.58667
# Epoch 5/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9674 - auc: 0.6827 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9656 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00005: val_accuracy did not improve from 0.58667
# Epoch 6/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9670 - auc: 0.6734 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00006: val_accuracy did not improve from 0.58667
# Epoch 7/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9688 - auc: 0.6723 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00007: val_accuracy did not improve from 0.58667
# Epoch 8/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9673 - auc: 0.6788 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00008: val_accuracy did not improve from 0.58667
# Epoch 9/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9667 - auc: 0.6856 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00009: val_accuracy did not improve from 0.58667
# Epoch 10/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9673 - auc: 0.6847 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9654 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00010: val_accuracy did not improve from 0.58667
# Epoch 11/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9671 - auc: 0.6786 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00011: val_accuracy did not improve from 0.58667
# Epoch 12/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9664 - auc: 0.6836 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00012: val_accuracy did not improve from 0.58667
# Epoch 13/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9670 - auc: 0.6694 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00013: val_accuracy did not improve from 0.58667
# Epoch 14/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9668 - auc: 0.6738 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00014: val_accuracy did not improve from 0.58667
# Epoch 15/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9667 - auc: 0.6779 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00015: val_accuracy did not improve from 0.58667
# Epoch 16/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9664 - auc: 0.6810 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00016: val_accuracy did not improve from 0.58667
# Epoch 17/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9671 - auc: 0.6756 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00017: val_accuracy did not improve from 0.58667
# Epoch 18/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9668 - auc: 0.6849 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00018: val_accuracy did not improve from 0.58667
# Epoch 19/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9675 - auc: 0.6760 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9662 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00019: val_accuracy did not improve from 0.58667
# Epoch 20/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9672 - auc: 0.6871 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9656 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00020: val_accuracy did not improve from 0.58667
# Epoch 21/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9665 - auc: 0.6856 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00021: val_accuracy did not improve from 0.58667
# Epoch 22/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9678 - auc: 0.6661 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00022: val_accuracy did not improve from 0.58667
# Epoch 23/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9668 - auc: 0.6798 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00023: val_accuracy did not improve from 0.58667
# Epoch 24/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9663 - auc: 0.6863 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00024: val_accuracy did not improve from 0.58667
# Epoch 25/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9693 - auc: 0.6639 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9658 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00025: val_accuracy did not improve from 0.58667
# Epoch 26/150
# 10/10 [==============================] - 0s 15ms/step - loss: 0.9680 - auc: 0.6658 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00026: val_accuracy did not improve from 0.58667
# Epoch 27/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9669 - auc: 0.6668 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00027: val_accuracy did not improve from 0.58667
# Epoch 28/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9668 - auc: 0.6687 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00028: val_accuracy did not improve from 0.58667
# Epoch 29/150
# 10/10 [==============================] - 0s 14ms/step - loss: 0.9674 - auc: 0.6764 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00029: val_accuracy did not improve from 0.58667
# Epoch 30/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9688 - auc: 0.6680 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00030: val_accuracy did not improve from 0.58667
# Epoch 31/150
# 10/10 [==============================] - 0s 13ms/step - loss: 0.9670 - auc: 0.6838 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00031: val_accuracy did not improve from 0.58667
# Epoch 32/150
# 10/10 [==============================] - 0s 16ms/step - loss: 0.9699 - auc: 0.6496 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00032: val_accuracy did not improve from 0.58667
# Epoch 33/150
# 10/10 [==============================] - 0s 17ms/step - loss: 0.9673 - auc: 0.6792 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9653 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00033: val_accuracy did not improve from 0.58667
# Epoch 34/150
# 10/10 [==============================] - 0s 17ms/step - loss: 0.9681 - auc: 0.6677 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00034: val_accuracy did not improve from 0.58667
# Epoch 35/150
# 10/10 [==============================] - 0s 18ms/step - loss: 0.9709 - auc: 0.6645 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9665 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00035: val_accuracy did not improve from 0.58667
# Epoch 36/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9672 - auc: 0.6849 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00036: val_accuracy did not improve from 0.58667
# Epoch 37/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9685 - auc: 0.6704 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00037: val_accuracy did not improve from 0.58667
# Epoch 38/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9669 - auc: 0.6841 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00038: val_accuracy did not improve from 0.58667
# Epoch 39/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9672 - auc: 0.6827 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00039: val_accuracy did not improve from 0.58667
# Epoch 40/150
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9678 - auc: 0.6775 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9654 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00040: val_accuracy did not improve from 0.58667
# Epoch 41/150
# 10/10 [==============================] - 0s 18ms/step - loss: 0.9665 - auc: 0.6854 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00041: val_accuracy did not improve from 0.58667
# Epoch 42/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9662 - auc: 0.6855 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00042: val_accuracy did not improve from 0.58667
# Epoch 43/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9668 - auc: 0.6807 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00043: val_accuracy did not improve from 0.58667
# Epoch 44/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9669 - auc: 0.6857 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00044: val_accuracy did not improve from 0.58667
# Epoch 45/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9676 - auc: 0.6770 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00045: val_accuracy did not improve from 0.58667
# Epoch 46/150
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9672 - auc: 0.6800 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00046: val_accuracy did not improve from 0.58667
# Epoch 47/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9673 - auc: 0.6707 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00047: val_accuracy did not improve from 0.58667
# Epoch 48/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9682 - auc: 0.6683 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9653 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00048: val_accuracy did not improve from 0.58667
# Epoch 49/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9675 - auc: 0.6825 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00049: val_accuracy did not improve from 0.58667
# Epoch 50/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9670 - auc: 0.6746 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00050: val_accuracy did not improve from 0.58667
# Epoch 51/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9672 - auc: 0.6802 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00051: val_accuracy did not improve from 0.58667
# Epoch 52/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9664 - auc: 0.6819 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00052: val_accuracy did not improve from 0.58667
# Epoch 53/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9669 - auc: 0.6798 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00053: val_accuracy did not improve from 0.58667
# Epoch 54/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9666 - auc: 0.6770 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00054: val_accuracy did not improve from 0.58667
# Epoch 55/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9669 - auc: 0.6655 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00055: val_accuracy did not improve from 0.58667
# Epoch 56/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9663 - auc: 0.6874 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00056: val_accuracy did not improve from 0.58667
# Epoch 57/150
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9675 - auc: 0.6727 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00057: val_accuracy did not improve from 0.58667
# Epoch 58/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9663 - auc: 0.6873 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00058: val_accuracy did not improve from 0.58667
# Epoch 59/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9680 - auc: 0.6613 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00059: val_accuracy did not improve from 0.58667
# Epoch 60/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9674 - auc: 0.6799 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00060: val_accuracy did not improve from 0.58667
# Epoch 61/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9700 - auc: 0.6575 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00061: val_accuracy did not improve from 0.58667
# Epoch 62/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9673 - auc: 0.6862 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00062: val_accuracy did not improve from 0.58667
# Epoch 63/150
# 10/10 [==============================] - 0s 27ms/step - loss: 0.9675 - auc: 0.6903 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9657 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00063: val_accuracy did not improve from 0.58667
# Epoch 64/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9680 - auc: 0.6768 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00064: val_accuracy did not improve from 0.58667
# Epoch 65/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9676 - auc: 0.6761 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00065: val_accuracy did not improve from 0.58667
# Epoch 66/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9670 - auc: 0.6833 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00066: val_accuracy did not improve from 0.58667
# Epoch 67/150
# 10/10 [==============================] - 0s 28ms/step - loss: 0.9675 - auc: 0.6775 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00067: val_accuracy did not improve from 0.58667
# Epoch 68/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9668 - auc: 0.6796 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00068: val_accuracy did not improve from 0.58667
# Epoch 69/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9666 - auc: 0.6842 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00069: val_accuracy did not improve from 0.58667
# Epoch 70/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9664 - auc: 0.6844 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00070: val_accuracy did not improve from 0.58667
# Epoch 71/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9666 - auc: 0.6816 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00071: val_accuracy did not improve from 0.58667
# Epoch 72/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9667 - auc: 0.6805 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00072: val_accuracy did not improve from 0.58667
# Epoch 73/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9669 - auc: 0.6690 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00073: val_accuracy did not improve from 0.58667
# Epoch 74/150
# 10/10 [==============================] - 0s 19ms/step - loss: 0.9667 - auc: 0.6820 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00074: val_accuracy did not improve from 0.58667
# Epoch 75/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9689 - auc: 0.6685 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9657 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00075: val_accuracy did not improve from 0.58667
# Epoch 76/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9670 - auc: 0.6814 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00076: val_accuracy did not improve from 0.58667
# Epoch 77/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9668 - auc: 0.6801 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00077: val_accuracy did not improve from 0.58667
# Epoch 78/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9668 - auc: 0.6795 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00078: val_accuracy did not improve from 0.58667
# Epoch 79/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9674 - auc: 0.6833 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00079: val_accuracy did not improve from 0.58667
# Epoch 80/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9664 - auc: 0.6871 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00080: val_accuracy did not improve from 0.58667
# Epoch 81/150
# 10/10 [==============================] - 0s 27ms/step - loss: 0.9669 - auc: 0.6699 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00081: val_accuracy did not improve from 0.58667
# Epoch 82/150
# 10/10 [==============================] - 0s 27ms/step - loss: 0.9666 - auc: 0.6815 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00082: val_accuracy did not improve from 0.58667
# Epoch 83/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9691 - auc: 0.6623 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9650 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00083: val_accuracy did not improve from 0.58667
# Epoch 84/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9677 - auc: 0.6708 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00084: val_accuracy did not improve from 0.58667
# Epoch 85/150
# 10/10 [==============================] - 0s 27ms/step - loss: 0.9669 - auc: 0.6791 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00085: val_accuracy did not improve from 0.58667
# Epoch 86/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9662 - auc: 0.6800 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00086: val_accuracy did not improve from 0.58667
# Epoch 87/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9682 - auc: 0.6648 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00087: val_accuracy did not improve from 0.58667
# Epoch 88/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9664 - auc: 0.6807 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00088: val_accuracy did not improve from 0.58667
# Epoch 89/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9667 - auc: 0.6829 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00089: val_accuracy did not improve from 0.58667
# Epoch 90/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9675 - auc: 0.6747 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00090: val_accuracy did not improve from 0.58667
# Epoch 91/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9675 - auc: 0.6705 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00091: val_accuracy did not improve from 0.58667
# Epoch 92/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9679 - auc: 0.6787 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00092: val_accuracy did not improve from 0.58667
# Epoch 93/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9671 - auc: 0.6836 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00093: val_accuracy did not improve from 0.58667
# Epoch 94/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9695 - auc: 0.6678 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9664 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00094: val_accuracy did not improve from 0.58667
# Epoch 95/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9676 - auc: 0.6837 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9658 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00095: val_accuracy did not improve from 0.58667
# Epoch 96/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9666 - auc: 0.6888 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00096: val_accuracy did not improve from 0.58667
# Epoch 97/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9674 - auc: 0.6669 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00097: val_accuracy did not improve from 0.58667
# Epoch 98/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9671 - auc: 0.6776 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00098: val_accuracy did not improve from 0.58667
# Epoch 99/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9671 - auc: 0.6773 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00099: val_accuracy did not improve from 0.58667
# Epoch 100/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9664 - auc: 0.6830 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00100: val_accuracy did not improve from 0.58667
# Epoch 101/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9666 - auc: 0.6804 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00101: val_accuracy did not improve from 0.58667
# Epoch 102/150
# 10/10 [==============================] - 0s 28ms/step - loss: 0.9662 - auc: 0.6902 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9662 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00102: val_accuracy did not improve from 0.58667
# Epoch 103/150
# 10/10 [==============================] - 0s 27ms/step - loss: 0.9676 - auc: 0.6824 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9669 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00103: val_accuracy did not improve from 0.58667
# Epoch 104/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9669 - auc: 0.6903 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9655 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00104: val_accuracy did not improve from 0.58667
# Epoch 105/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9679 - auc: 0.6673 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00105: val_accuracy did not improve from 0.58667
# Epoch 106/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9670 - auc: 0.6783 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00106: val_accuracy did not improve from 0.58667
# Epoch 107/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9669 - auc: 0.6839 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00107: val_accuracy did not improve from 0.58667
# Epoch 108/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9672 - auc: 0.6739 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9643 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00108: val_accuracy did not improve from 0.58667
# Epoch 109/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9665 - auc: 0.6814 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00109: val_accuracy did not improve from 0.58667
# Epoch 110/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9670 - auc: 0.6741 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00110: val_accuracy did not improve from 0.58667
# Epoch 111/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9673 - auc: 0.6803 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00111: val_accuracy did not improve from 0.58667
# Epoch 112/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9667 - auc: 0.6806 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00112: val_accuracy did not improve from 0.58667
# Epoch 113/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9669 - auc: 0.6754 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00113: val_accuracy did not improve from 0.58667
# Epoch 114/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9663 - auc: 0.6867 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00114: val_accuracy did not improve from 0.58667
# Epoch 115/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9668 - auc: 0.6691 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00115: val_accuracy did not improve from 0.58667
# Epoch 116/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9677 - auc: 0.6732 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9655 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00116: val_accuracy did not improve from 0.58667
# Epoch 117/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9694 - auc: 0.6540 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00117: val_accuracy did not improve from 0.58667
# Epoch 118/150
# 10/10 [==============================] - 0s 26ms/step - loss: 0.9666 - auc: 0.6793 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00118: val_accuracy did not improve from 0.58667
# Epoch 119/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9676 - auc: 0.6767 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9656 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00119: val_accuracy did not improve from 0.58667
# Epoch 120/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9676 - auc: 0.6780 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9653 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00120: val_accuracy did not improve from 0.58667
# Epoch 121/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9673 - auc: 0.6757 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00121: val_accuracy did not improve from 0.58667
# Epoch 122/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9674 - auc: 0.6679 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00122: val_accuracy did not improve from 0.58667
# Epoch 123/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9663 - auc: 0.6858 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00123: val_accuracy did not improve from 0.58667
# Epoch 124/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9664 - auc: 0.6829 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9655 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00124: val_accuracy did not improve from 0.58667
# Epoch 125/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9676 - auc: 0.6762 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9656 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00125: val_accuracy did not improve from 0.58667
# Epoch 126/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9675 - auc: 0.6800 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9649 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00126: val_accuracy did not improve from 0.58667
# Epoch 127/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9669 - auc: 0.6770 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00127: val_accuracy did not improve from 0.58667
# Epoch 128/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9669 - auc: 0.6796 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9652 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00128: val_accuracy did not improve from 0.58667
# Epoch 129/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9681 - auc: 0.6766 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9656 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00129: val_accuracy did not improve from 0.58667
# Epoch 130/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9671 - auc: 0.6808 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00130: val_accuracy did not improve from 0.58667
# Epoch 131/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9667 - auc: 0.6805 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00131: val_accuracy did not improve from 0.58667
# Epoch 132/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9672 - auc: 0.6717 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9645 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00132: val_accuracy did not improve from 0.58667
# Epoch 133/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9674 - auc: 0.6777 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00133: val_accuracy did not improve from 0.58667
# Epoch 134/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9677 - auc: 0.6723 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00134: val_accuracy did not improve from 0.58667
# Epoch 135/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9665 - auc: 0.6850 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9643 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00135: val_accuracy did not improve from 0.58667
# Epoch 136/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9665 - auc: 0.6849 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9644 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00136: val_accuracy did not improve from 0.58667
# Epoch 137/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9677 - auc: 0.6734 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00137: val_accuracy did not improve from 0.58667
# Epoch 138/150
# 10/10 [==============================] - 0s 20ms/step - loss: 0.9663 - auc: 0.6824 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00138: val_accuracy did not improve from 0.58667
# Epoch 139/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9674 - auc: 0.6714 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9648 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00139: val_accuracy did not improve from 0.58667
# Epoch 140/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9665 - auc: 0.6877 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9653 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00140: val_accuracy did not improve from 0.58667
# Epoch 141/150
# 10/10 [==============================] - 0s 22ms/step - loss: 0.9681 - auc: 0.6804 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9668 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00141: val_accuracy did not improve from 0.58667
# Epoch 142/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9675 - auc: 0.6797 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00142: val_accuracy did not improve from 0.58667
# Epoch 143/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9673 - auc: 0.6682 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00143: val_accuracy did not improve from 0.58667
# Epoch 144/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9660 - auc: 0.6908 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9651 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00144: val_accuracy did not improve from 0.58667
# Epoch 145/150
# 10/10 [==============================] - 0s 25ms/step - loss: 0.9669 - auc: 0.6821 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9655 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00145: val_accuracy did not improve from 0.58667
# Epoch 146/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9677 - auc: 0.6716 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9657 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00146: val_accuracy did not improve from 0.58667
# Epoch 147/150
# 10/10 [==============================] - 0s 21ms/step - loss: 0.9670 - auc: 0.6824 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9647 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00147: val_accuracy did not improve from 0.58667
# Epoch 148/150
# 10/10 [==============================] - 0s 24ms/step - loss: 0.9670 - auc: 0.6702 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6933 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00148: val_accuracy did not improve from 0.58667
# Epoch 149/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9664 - auc: 0.6854 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9646 - val_auc: 0.6900 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00149: val_accuracy did not improve from 0.58667
# Epoch 150/150
# 10/10 [==============================] - 0s 23ms/step - loss: 0.9677 - auc: 0.6748 - accuracy: 0.5853 - precision: 0.5853 - recall: 0.5853 - val_loss: 0.9655 - val_auc: 0.6867 - val_accuracy: 0.5867 - val_precision: 0.5867 - val_recall: 0.5867
#
# Epoch 00150: val_accuracy did not improve from 0.58667

# %% [markdown]
# ############################

# %% [markdown]
# ## ROC - AUC Curve

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)  # Get the class with the highest probability
y_test_np = y_test.to_numpy()  # Convert y_test to numpy array

# Accuracy
accuracy = accuracy_score(np.argmax(y_test_np, axis=1), y_pred)

# ROC-AUC Curve (One-vs-Rest)
n_classes = y_test_np.shape[1]
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_np[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot the ROC-AUC Curves for each class
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f'Class {["Apnea", "Normal", "Insomnia"][i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve (One-vs-Rest)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Precision - Recall Curve (One vs Rest)

# %%
precision = {}
recall = {}
pr_auc = {}

for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_test_np[:, i], y_pred_prob[:, i])
    pr_auc[i] = auc(recall[i], precision[i])

# Plot the Precision-Recall curves for each class
plt.figure(figsize=(10, 6))
for i in range(n_classes):
    plt.plot(recall[i], precision[i], label=f'Class {["Apnea", "Normal", "Insomnia"][i]} (AUC = {pr_auc[i]:.2f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (One-vs-Rest)')
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
cm = confusion_matrix(np.argmax(y_test_np, axis=1), y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Apnea', 'Normal', 'Insomnia'], yticklabels=['Apnea', 'Normal', 'Insomnia'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Print Accuracy
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.97

# %% [markdown]
# ## Training History (Accuracy and Loss) over Epochs

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'auc', 'accuracy', 'precision', 'recall', 'val_loss', 'val_auc', 'val_accuracy', 'val_precision', 'val_recall'])

# %%
plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Print Accuracy
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.97

# %% [markdown]
# ## Classification Report

# %%
report = classification_report(np.argmax(y_test_np, axis=1), y_pred, target_names=['Apnea', 'Normal', 'Insomnia'])
print('Classification Report:')
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        Apnea       0.89      1.00      0.94        16
#       Normal       1.00      1.00      1.00        44
#     Insomnia       1.00      0.87      0.93        15
#
#     accuracy                           0.97        75
#    macro avg       0.96      0.96      0.96        75
# weighted avg       0.98      0.97      0.97        75

# %%
# Load the best model saved during training
best_model = load_model('best_model.h5')

# Get the final accuracy and other metrics on the validation set
loss, ac, accuracy, precision, recall = best_model.evaluate(X_test, y_test)
y_pred_prob = best_model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)  # Get the predicted class with the highest probability
y_test_np = y_test.to_numpy()
cm = confusion_matrix(np.argmax(y_test_np, axis=1), y_pred)
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Apnea', 'Normal', 'Insomnia'], yticklabels=['Apnea', 'Normal', 'Insomnia'])
plt.title('Confusion Matrix - Best Model')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Print the results
print(f"Best Model Stored - Accuracy: {accuracy:.4f}, Loss: {loss:.4f}")
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC: {ac:.4f}")
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1294 - auc: 0.9990 - accuracy: 0.9867 - precision: 0.9865 - recall: 0.9733
# Best Model Stored - Accuracy: 0.9867, Loss: 0.1294
# Precision: 0.9865, Recall: 0.9733, AUC: 0.9990

# %%
# Load the best model saved during training
best_model = load_model('best_model.h5')

# Get the final accuracy and other metrics on the validation set
loss, ac, accuracy, precision, recall = best_model.evaluate(X_train, y_train, batch_size = 32)
y_pred_prob = best_model.predict(X_train)
y_pred = np.argmax(y_pred_prob, axis=1)  # Get the predicted class with the highest probability
y_test_np = y_train.to_numpy()
cm = confusion_matrix(np.argmax(y_test_np, axis=1), y_pred)
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Apnea', 'Normal', 'Insomnia'], yticklabels=['Apnea', 'Normal', 'Insomnia'])
plt.title('Confusion Matrix - Best Model')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Print the results
print(f"Best Model Stored - Accuracy: {accuracy:.4f}, Loss: {loss:.4f}")
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, AUC: {ac:.4f}")
# Out:
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3341 - auc: 0.9580 - accuracy: 0.9097 - precision: 0.9097 - recall: 0.9097
# Best Model Stored - Accuracy: 0.9097, Loss: 0.3341
# Precision: 0.9097, Recall: 0.9097, AUC: 0.9580

# %% [markdown]
# # ####

# %%
from sklearn.model_selection import train_test_split

# Features and target
X = ml_data.drop(columns=['Sleep_Disorder_Target'])
y = ml_data['Sleep_Disorder_Target']

# Stratified split to maintain class distribution
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Training set size: 280
# Test set size: 94

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import label_binarize

# Initialize the model
rf_model = RandomForestClassifier(n_estimators=50, max_depth=4, random_state=42, n_jobs=-1)

# Train the model
rf_model.fit(X_train, y_train)

# Predict on test data
y_pred = rf_model.predict(X_test)
y_pred_prob = rf_model.predict_proba(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Classification Report
report = classification_report(y_test, y_pred, target_names=['Normal', 'Insomnia', 'Apnea'])

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# ROC AUC Curve (One-vs-Rest)
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])  # Binarize the output
fpr, tpr, roc_auc = {}, {}, {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Display metrics
print(f"Random Forest - Accuracy: {accuracy:.4f}")
print(f"Classification Report:\n{report}")

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Insomnia', 'Apnea'], yticklabels=['Normal', 'Insomnia', 'Apnea'])
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve (One-vs-Rest)
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {["Normal", "Insomnia", "Apnea"][i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend(loc='lower right')
plt.show()
# Out:
# Random Forest - Accuracy: 0.8830
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.93      0.91        55
#     Insomnia       0.85      0.85      0.85        20
#        Apnea       0.88      0.79      0.83        19
#
#     accuracy                           0.88        94
#    macro avg       0.88      0.86      0.86        94
# weighted avg       0.88      0.88      0.88        94

# %%
# Predict on test data
y_pred = rf_model.predict(X_train)
y_pred_prob = rf_model.predict_proba(X_train)

# Accuracy
accuracy = accuracy_score(y_train, y_pred)

# Classification Report
report = classification_report(y_train, y_pred, target_names=['Normal', 'Insomnia', 'Apnea'])

# Confusion Matrix
cm = confusion_matrix(y_train, y_pred)

# ROC AUC Curve (One-vs-Rest)
y_test_bin = label_binarize(y_train, classes=[0, 1, 2])  # Binarize the output
fpr, tpr, roc_auc = {}, {}, {}
for i in range(3):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Display metrics
print(f"Random Forest - Accuracy: {accuracy:.4f}")
print(f"Classification Report:\n{report}")

# Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Insomnia', 'Apnea'], yticklabels=['Normal', 'Insomnia', 'Apnea'])
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# ROC Curve (One-vs-Rest)
plt.figure(figsize=(10, 6))
for i in range(3):
    plt.plot(fpr[i], tpr[i], label=f'Class {["Normal", "Insomnia", "Apnea"][i]} (AUC = {roc_auc[i]:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend(loc='lower right')
plt.show()
# Out:
# Random Forest - Accuracy: 0.9286
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.95      0.95       164
#     Insomnia       0.90      0.90      0.90        58
#        Apnea       0.87      0.91      0.89        58
#
#     accuracy                           0.93       280
#    macro avg       0.91      0.92      0.91       280
# weighted avg       0.93      0.93      0.93       280
