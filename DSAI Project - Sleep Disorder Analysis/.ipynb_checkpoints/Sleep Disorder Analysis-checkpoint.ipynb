# %% [markdown]
# # Sleep Disorder Analysis

# %%
import opendatasets as od
 
od.download(
    "https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: mindhawk
# Your Kaggle Key: ········
# Dataset URL: https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 2.54k/2.54k [00:00<00:00, 1.30MB/s]

# %% [markdown]
# ## Importing all the required Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn import ensemble
from IPython.display import clear_output
import os

# %% [markdown]
# ## The Data

# %%
file =('sleep-health-and-lifestyle-dataset\\Sleep_health_and_lifestyle_dataset.csv')
data = pd.read_csv(file)
 
# displaying the contents of the XLSX file
data.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
data.Occupation.unique(), len(data.Occupation.unique())
# Out:
# (array(['Software Engineer', 'Doctor', 'Sales Representative', 'Teacher',
#         'Nurse', 'Engineer', 'Accountant', 'Scientist', 'Lawyer',
#         'Salesperson', 'Manager'], dtype=object),
#  11)

# %%
data['BMI Category'].unique(), len(data['BMI Category'].unique())
# Out:
# (array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object), 4)

# %%
data['Sleep Disorder'].unique(), len(data['Sleep Disorder'].unique())
# Out:
# (array(['None', 'Sleep Apnea', 'Insomnia'], dtype=object), 3)

# %%
genMap = {'Male': 0, 'Female': 1}
# data['Gender'] = (data['Gender'] == 'Male')? 0:1
data.Gender = data.Gender.map(genMap)
bmiMap = {'Normal': 0, 'Normal Weight': 0, 'Overweight':1, 'Obese': 2}
data['BMI Category'] = data['BMI Category'].map(bmiMap)
data.head()
# Out:
#    Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0          1       0   27     Software Engineer             6.1
# 1          2       0   28                Doctor             6.2
# 2          3       0   28                Doctor             6.2
# 3          4       0   28  Sales Representative             5.9
# 4          5       0   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level  BMI Category  \
# 0                 6                       42             6             1
# 1                 6                       60             8             0
# 2                 6                       60             8             0
# 3                 4                       30             8             2
# 4                 4                       30             8             2
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
val = data.values

# %%
data.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...
